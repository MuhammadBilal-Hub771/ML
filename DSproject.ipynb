# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadBilal-Hub771/ML/blob/DataScience/DSproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![IAC.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Exploratory Data Analysis (EDA) of AAPL Stock Data**
#
# I'll perform a comprehensive EDA on the AAPL stock dataset from 1980 to 1986 using Python with Pandas, Numpy, and Matplotlib.

# %% [markdown]
# **SCHOOL OF Informatics &amp; Robotics**
#
# **Bachelor of Science in Computer Science**
#
# Assignment-1

# %% [markdown]
# **a) Exploratory Data Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('AAPL.csv')

# Convert Date to datetime and set as index
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Display basic info
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10409 entries, 1980-12-12 to 2022-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       10409 non-null  float64
#  1   High       10409 non-null  float64
#  2   Low        10409 non-null  float64
#  3   Close      10409 non-null  float64
#  4   Adj Close  10409 non-null  float64
#  5   Volume     10409 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 569.2 KB
# None
#                Open          High           Low         Close     Adj Close  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      13.959910     14.111936     13.809163     13.966757     13.350337
# std       30.169244     30.514878     29.835055     30.191696     29.911132
# min        0.049665      0.049665      0.049107      0.049107      0.038384
# 25%        0.281964      0.287946      0.274554      0.281250      0.234799
# ...

# %%
# Load the data
df = pd.read_csv('AAPL.csv')

# %%
# Convert Date to datetime and set as index
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
# Display basic info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10409 entries, 1980-12-12 to 2022-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       10409 non-null  float64
#  1   High       10409 non-null  float64
#  2   Low        10409 non-null  float64
#  3   Close      10409 non-null  float64
#  4   Adj Close  10409 non-null  float64
#  5   Volume     10409 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 569.2 KB
# None

# %%
print(df.describe())
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      13.959910     14.111936     13.809163     13.966757     13.350337
# std       30.169244     30.514878     29.835055     30.191696     29.911132
# min        0.049665      0.049665      0.049107      0.049107      0.038384
# 25%        0.281964      0.287946      0.274554      0.281250      0.234799
# 50%        0.468750      0.477679      0.459821      0.468750      0.386853
# 75%       14.217857     14.364286     14.043571     14.206071     12.188149
# max      182.630005    182.940002    179.119995    182.009995    181.778397
#
#              Volume
# count  1.040900e+04
# mean   3.321778e+08
# std    3.393344e+08
# min    0.000000e+00
# 25%    1.247604e+08
# 50%    2.199680e+08
# 75%    4.126108e+08
# max    7.421641e+09

# %%
print(df.isnull().sum())  # Count missing values in each column
# Out:
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume         0
# Daily Range    0
# dtype: int64

# %% [markdown]
# **1. Time Series Plot of Closing Price**

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Close'], label='Closing Price')
plt.title('AAPL Stock Price (1980-1986)')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Explanation:** This line plot shows the historical closing prices of AAPL stock. We can observe:
#
# The stock started trading at around $0.13 in December 1980
#
# Significant volatility in the early years
#
# A major price increase in early 1983
#
# A sharp decline in late 1983
#
# Gradual recovery through 1984-1986

# %% [markdown]
# **2. Volume Analysis**

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Volume'], label='Trading Volume', color='orange')
plt.title('AAPL Trading Volume (1980-1986)')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Explanation**: This shows the trading volume over time. Key observations:
#
# Extremely high volume on the first trading day (IPO)
#
# Periodic spikes in volume corresponding to major price movements
#
# Generally higher volume during periods of price volatili

# %% [markdown]
# **3. Daily Price Range Analysis**

# %%
df['Daily Range'] = df['High'] - df['Low']
plt.figure(figsize=(14, 7))
plt.plot(df['Daily Range'], label='Daily Price Range', color='green')
plt.title('AAPL Daily Price Range (1980-1986)')
plt.xlabel('Date')
plt.ylabel('Price Range ($)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Explanation**:This shows the difference between daily high and low prices. We can see:
#
# The price range was very small in the early years (fractions of a cent)
#
# Range expanded significantly during volatile periods
#
# Largest ranges occurred during the 1983 price surge and subsequent correction

# %% [markdown]
# **4. Monthly Average Closing Price**

# %%
monthly_avg = df['Close'].resample('M').mean()
plt.figure(figsize=(14, 7))
monthly_avg.plot(label='Monthly Average Close')
plt.title('AAPL Monthly Average Closing Price (1980-1986)')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-6-3610540762.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_avg = df['Close'].resample('M').mean()

# %% [markdown]
# **Explanation**: This smooths out the daily fluctuations to show monthly trends. Key points:
#
# Steady rise from 1980 to early 1983
#
# Sharp peak in January 1983
#
# Significant correction through 1983
#
# Gradual recovery through 1984-1986

# %% [markdown]
# **b) Histograms and Box Plots**
#
# First 3 Attributes (Open, High, Low)

# %%
# Histograms
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
df['Open'].hist(ax=axes[0], bins=50, color='blue')
axes[0].set_title('Open Price Distribution')
df['High'].hist(ax=axes[1], bins=50, color='green')
axes[1].set_title('High Price Distribution')
df['Low'].hist(ax=axes[2], bins=50, color='red')
axes[2].set_title('Low Price Distribution')
plt.tight_layout()
plt.show()

# Box plots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
df['Open'].plot(kind='box', ax=axes[0], vert=False)
axes[0].set_title('Open Price')
df['High'].plot(kind='box', ax=axes[1], vert=False)
axes[1].set_title('High Price')
df['Low'].plot(kind='box', ax=axes[2], vert=False)
axes[2].set_title('Low Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# Last 3 Attributes (Adj Close, Volume, Daily Range)

# %%
# Histograms
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
df['Adj Close'].hist(ax=axes[0], bins=50, color='purple')
axes[0].set_title('Adj Close Distribution')
df['Volume'].hist(ax=axes[1], bins=50, color='orange')
axes[1].set_title('Volume Distribution')
df['Daily Range'].hist(ax=axes[2], bins=50, color='cyan')
axes[2].set_title('Daily Range Distribution')
plt.tight_layout()
plt.show()

# Box plots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
df['Adj Close'].plot(kind='box', ax=axes[0], vert=False)
axes[0].set_title('Adj Close')
df['Volume'].plot(kind='box', ax=axes[1], vert=False)
axes[1].set_title('Volume')
df['Daily Range'].plot(kind='box', ax=axes[2], vert=False)
axes[2].set_title('Daily Range')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation**: The histograms show the distribution of values for each attribute, while the box plots show the median, quartiles, and outliers. Key observations:
#
# Price attributes (Open, High, Low, Close, Adj Close) have similar distributions
#
# Volume is extremely right-skewed with many outliers
#
# Daily Range shows most days had small price movements with some extreme outliers

# %% [markdown]
# **c) Correlation Matrix Plot**

# %%
# Calculate correlations
corr = df.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of AAPL Stock Data')
plt.show()

# %% [markdown]
# **Explanation**: The correlation matrix shows:
#
# Price attributes (Open, High, Low, Close, Adj Close) are nearly perfectly correlated (≈1.0)
#
# Volume has weak negative correlation with prices (-0.1 to -0.2)
#
# Daily Range has moderate positive correlation with prices (0.4-0.5)

# %% [markdown]
# **d) Density Plots of Last 3 Attributes**

# %%
# Density plots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
df['Adj Close'].plot(kind='density', ax=axes[0])
axes[0].set_title('Adj Close Density')
df['Volume'].plot(kind='density', ax=axes[1])
axes[1].set_title('Volume Density')
df['Daily Range'].plot(kind='density', ax=axes[2])
axes[2].set_title('Daily Range Density')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explanation**: The density plots show the probability distribution of values:
#
# Adj Close has a multi-modal distribution reflecting different price regimes
#
# Volume is extremely right-skewed, with most days having lower volume
#
# Daily Range shows most days had very small price movements with a long right tail

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Create target variable (1 if price goes up next day, 0 if down or same)
df['Target'] = (df['Close'].shift(-1) > df['Close']).astype(int)

# %%
def compute_rsi(data, window):
    """
    Computes the Relative Strength Index (RSI) for a given data series.

    Args:
        data (pd.Series): The data series (e.g., closing prices) to compute RSI on.
        window (int): The lookback window for the RSI calculation.

    Returns:
        pd.Series: The RSI values.
    """
    diff = data.diff()
    gain = diff.where(diff > 0, 0)
    loss = -diff.where(diff < 0, 0)

    avg_gain = gain.rolling(window=window, min_periods=1).mean()
    avg_loss = loss.rolling(window=window, min_periods=1).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))

    return rsi

# %%
# Create features
df['Price_Change'] = df['Close'].pct_change()
df['Volume_Change'] = df['Volume'].pct_change()
df['5_day_MA'] = df['Close'].rolling(window=5).mean()
df['10_day_MA'] = df['Close'].rolling(window=10).mean()
df['5_day_Std'] = df['Close'].rolling(window=5).std()
df['RSI'] = compute_rsi(df['Close'], 14)

# %%
# Drop NaN and infinite values created by feature engineering
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# %%
# Select features and target
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'Price_Change',
            'Volume_Change', '5_day_MA', '10_day_MA', '5_day_Std', 'RSI']
X = df[features]
y = df['Target']

# %%
# Train-test split (time-series aware)
split_date = '1985-01-01'
X_train = X[X.index < split_date]
X_test = X[X.index >= split_date]
y_train = y[y.index < split_date]
y_test = y[y.index >= split_date]

# %%
# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-71-2480350996.py in <cell line: 0>()
#       1 # Scale features
#       2 scaler = StandardScaler()
# ----> 3 X_train_scaled = scaler.fit_transform(X_train)
#       4 X_test_scaled = scaler.transform(X_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...

# %% [markdown]
# ## Scale features
#
# ### Subtask:
# Scale the training and testing features using `StandardScaler`.

# %% [markdown]
# **Reasoning**:
# Inspect the X_train and X_test dataframes for infinite values and drop rows with these values, then scale the features using StandardScaler.

# %%
# Inspect for infinite values in X_train
print("Infinite values in X_train:", X_train.isin([np.inf, -np.inf]).sum().sum())
# Inspect for infinite values in X_test
print("Infinite values in X_test:", X_test.isin([np.inf, -np.inf]).sum().sum())

# Replace infinite values with NaN and drop rows
X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
X_test.replace([np.inf, -np.inf], np.nan, inplace=True)

X_train.dropna(inplace=True)
X_test.dropna(inplace=True)

# Ensure y_train and y_test correspond to the cleaned X_train and X_test
y_train = y_train.loc[X_train.index]
y_test = y_test.loc[X_test.index]


# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# Infinite values in X_train: 1
# Infinite values in X_test: 0
# /tmp/ipython-input-29-2591609150.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
# /tmp/ipython-input-29-2591609150.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.replace([np.inf, -np.inf], np.nan, inplace=True)
# /tmp/ipython-input-29-2591609150.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ## Train model
#
# ### Subtask:
# Train a RandomForestClassifier model on the scaled training data.

# %% [markdown]
# **Reasoning**:
# Train a RandomForestClassifier model on the scaled training data.

# %%
# Instantiate and train RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## Evaluate model
#
# ### Subtask:
# Evaluate the trained model's performance on the scaled testing data using appropriate metrics.

# %% [markdown]
# **Reasoning**:
# Make predictions on the scaled test data and evaluate the model's performance using a classification report and accuracy score.

# %%
# Make predictions
y_pred = model.predict(X_test_scaled)

# Evaluate the model
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.96      0.66      4689
#            1       0.50      0.04      0.08      4695
#
#     accuracy                           0.50      9384
#    macro avg       0.50      0.50      0.37      9384
# weighted avg       0.50      0.50      0.37      9384
#
# Accuracy: 0.5

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The initial inspection revealed one infinite value in the training features (`X_train`).
# *   After handling infinite values and NaNs, the training and testing data were successfully scaled using `StandardScaler`.
# *   A `RandomForestClassifier` was trained on the scaled training data.
# *   Model evaluation on the scaled testing data showed poor performance, with an accuracy of 0.50 and low precision, recall, and F1-scores for both classes.
#
# ### Insights or Next Steps
#
# *   The model's performance indicates it is no better than random guessing. Further investigation into feature engineering, hyperparameter tuning, or exploring different models is necessary.
# *   The dataset might be imbalanced, which could explain the poor performance, particularly for class 1. Techniques for handling imbalanced data should be considered.

# %%
def compute_rsi(series, window=14):
    delta = series.diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)

    avg_gain = gain.rolling(window=window).mean()
    avg_loss = loss.rolling(window=window).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# %%
# Initialize and train the model
model = RandomForestClassifier(n_estimators=100,
                              random_state=42,
                              max_depth=5,
                              class_weight='balanced')
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=5, random_state=42)

# %%
# Make predictions
train_preds = model.predict(X_train_scaled)
test_preds = model.predict(X_test_scaled)

# %%
# Evaluate model
print("Training Accuracy:", accuracy_score(y_train, train_preds))
print("Test Accuracy:", accuracy_score(y_test, test_preds))
print("\nClassification Report (Test Set):")
print(classification_report(y_test, test_preds))
# Out:
# Training Accuracy: 0.7339901477832512
# Test Accuracy: 0.4998934356351236
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.50      0.95      0.66      4689
#            1       0.50      0.05      0.09      4695
#
#     accuracy                           0.50      9384
#    macro avg       0.50      0.50      0.37      9384
# weighted avg       0.50      0.50      0.37      9384

# %%
# Get feature importances
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
# Plot feature importances
plt.figure(figsize=(12, 6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), [features[i] for i in indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve

# Confusion Matrix
cm = confusion_matrix(y_test, test_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# ROC Curve
y_probs = model.predict_proba(X_test_scaled)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
auc_score = roc_auc_score(y_test, y_probs)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'Random Forest (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
# Random Forest (Bagging)
rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    min_samples_split=5,
    random_state=42,
    class_weight='balanced'
)

# %%
rf_model.fit(X_train_scaled, y_train)
rf_preds = rf_model.predict(X_test_scaled)
rf_probs = rf_model.predict_proba(X_test_scaled)[:, 1]

# %%
# Evaluate
rf_accuracy = accuracy_score(y_test, rf_preds)
rf_auc = roc_auc_score(y_test, rf_probs)
print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
print(f"Random Forest ROC AUC: {rf_auc:.4f}")
# Out:
# Random Forest Accuracy: 0.5003
# Random Forest ROC AUC: 0.4942

# %%
from xgboost import XGBClassifier

# %%
# XGBoost (Boosting)
xgb_model = XGBClassifier(
    n_estimators=150,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    scale_pos_weight=np.sum(y_train == 0) / np.sum(y_train == 1)  # Handle imbalance
)

# %%
xgb_model.fit(X_train_scaled, y_train)
xgb_preds = xgb_model.predict(X_test_scaled)
xgb_probs = xgb_model.predict_proba(X_test_scaled)[:, 1]

# %%
# Evaluate
xgb_accuracy = accuracy_score(y_test, xgb_preds)
xgb_auc = roc_auc_score(y_test, xgb_probs)
print(f"XGBoost Accuracy: {xgb_accuracy:.4f}")
print(f"XGBoost ROC AUC: {xgb_auc:.4f}")
# Out:
# XGBoost Accuracy: 0.4961
# XGBoost ROC AUC: 0.4950

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Logistic Regression
lr_model = LogisticRegression(
    penalty='l2',
    C=0.1,
    max_iter=1000,
    random_state=42,
    class_weight='balanced'
)

# %%
lr_model.fit(X_train_scaled, y_train)
lr_preds = lr_model.predict(X_test_scaled)
lr_probs = lr_model.predict_proba(X_test_scaled)[:, 1]

# %%
# Evaluate
lr_accuracy = accuracy_score(y_test, lr_preds)
lr_auc = roc_auc_score(y_test, lr_probs)
print(f"Logistic Regression Accuracy: {lr_accuracy:.4f}")
print(f"Logistic Regression ROC AUC: {lr_auc:.4f}")
# Out:
# Logistic Regression Accuracy: 0.4983
# Logistic Regression ROC AUC: 0.4739

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                            f1_score, roc_auc_score, confusion_matrix,
                            classification_report)

# %%
# Create comparison table
results = pd.DataFrame({
    'Model': ['Random Forest (Bagging)', 'XGBoost (Boosting)', 'Logistic Regression'],
    'Accuracy': [rf_accuracy, xgb_accuracy, lr_accuracy],
    'ROC AUC': [rf_auc, xgb_auc, lr_auc],
    'Precision': [
        precision_score(y_test, rf_preds),
        precision_score(y_test, xgb_preds),
        precision_score(y_test, lr_preds)
    ],
    'Recall': [
        recall_score(y_test, rf_preds),
        recall_score(y_test, xgb_preds),
        recall_score(y_test, lr_preds)
    ],
    'F1 Score': [
        f1_score(y_test, rf_preds),
        f1_score(y_test, xgb_preds),
        f1_score(y_test, lr_preds)
    ]
})

print("\nModel Comparison:")
print(results.round(4))

# Plot ROC curves
plt.figure(figsize=(10, 8))
for model, probs, label in zip(
    [rf_model, xgb_model, lr_model],
    [rf_probs, xgb_probs, lr_probs],
    ['Random Forest', 'XGBoost', 'Logistic Regression']
):
    fpr, tpr, _ = roc_curve(y_test, probs)
    auc_score = roc_auc_score(y_test, probs)
    plt.plot(fpr, tpr, label=f'{label} (AUC = {auc_score:.3f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend()
plt.show()
# Out:
# Model Comparison:
#                      Model  Accuracy  ROC AUC  Precision  Recall  F1 Score
# 0  Random Forest (Bagging)    0.5003   0.4942     0.5059  0.0545    0.0984
# 1       XGBoost (Boosting)    0.4961   0.4950     0.4772  0.0756    0.1305
# 2      Logistic Regression    0.4983   0.4739     0.4935  0.1044    0.1723

# %%
# Plot feature importances for tree-based models
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Random Forest feature importance
rf_importances = pd.Series(rf_model.feature_importances_, index=features)
rf_importances.sort_values().plot(kind='barh', ax=ax1, color='green')
ax1.set_title('Random Forest Feature Importance')

# XGBoost feature importance
xgb_importances = pd.Series(xgb_model.feature_importances_, index=features)
xgb_importances.sort_values().plot(kind='barh', ax=ax2, color='blue')
ax2.set_title('XGBoost Feature Importance')

plt.tight_layout()
plt.show()

# Logistic Regression coefficients
lr_coef = pd.Series(lr_model.coef_[0], index=features)
plt.figure(figsize=(10, 6))
lr_coef.sort_values().plot(kind='barh', color='purple')
plt.title('Logistic Regression Coefficients')
plt.show()

# %%
# Plot confusion matrices
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

models = [('Random Forest', rf_preds),
          ('XGBoost', xgb_preds),
          ('Logistic Regression', lr_preds)]

for idx, (name, preds) in enumerate(models):
    cm = confusion_matrix(y_test, preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx])
    axes[idx].set_title(f'{name} Confusion Matrix')
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split, TimeSeriesSplit

# %%
# Time Series Cross Validation for all models
tscv = TimeSeriesSplit(n_splits=5)
models = {
    'Random Forest': RandomForestClassifier(n_estimators=200, max_depth=8, random_state=42),
    'XGBoost': XGBClassifier(n_estimators=150, max_depth=6, learning_rate=0.05, random_state=42),
    'Logistic Regression': LogisticRegression(C=0.1, max_iter=1000, random_state=42)
}

results_tscv = {name: {'accuracy': [], 'auc': []} for name in models.keys()}

for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Drop NaN and infinite values created by feature engineering within the fold
    X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
    X_test.replace([np.inf, -np.inf], np.nan, inplace=True)
    X_train.dropna(inplace=True)
    X_test.dropna(inplace=True)

    # Ensure y_train and y_test correspond to the cleaned X_train and X_test
    y_train = y_train.loc[X_train.index]
    y_test = y_test.loc[X_test.index]

    # Scale features
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    for name, model in models.items():
        model.fit(X_train_scaled, y_train)
        preds = model.predict(X_test_scaled)
        probs = model.predict_proba(X_test_scaled)[:, 1]

        results_tscv[name]['accuracy'].append(accuracy_score(y_test, preds))
        results_tscv[name]['auc'].append(roc_auc_score(y_test, probs))

# Print average performance across folds
print("\nTime Series Cross-Validation Results:")
for name in results_tscv:
    avg_acc = np.mean(results_tscv[name]['accuracy'])
    avg_auc = np.mean(results_tscv[name]['auc'])
    print(f"{name}: Avg Accuracy = {avg_acc:.4f}, Avg AUC = {avg_auc:.4f}")
# Out:
# /tmp/ipython-input-72-2581525302.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
# /tmp/ipython-input-72-2581525302.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.replace([np.inf, -np.inf], np.nan, inplace=True)
# /tmp/ipython-input-72-2581525302.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.dropna(inplace=True)
# ...
