# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadBilal-Hub771/ML/blob/AI/FlaskApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Apne folder ka path yahan dein
folder_path = "/content/drive/MyDrive/PakvoiceAI"

# Us folder ke andar ki saari files ki list haasil karein
files = os.listdir(folder_path)

print("Aap ke folder mein yeh files hain:")
print(files)
# Out:
# Aap ke folder mein yeh files hain:
# ['.ipynb_checkpoints', 'app.py', 'requirements.txt', 'templates']

# %%
# 3. Install packages
# !pip install -q Flask Werkzeug pyngrok flask-ngrok

# %%
# Get your ngrok token from: https://dashboard.ngrok.com/get-started/your-authtoken
from pyngrok import ngrok
import os

os.chdir('/content/drive/MyDrive/PakvoiceAI')

# Replace with YOUR token
ngrok.set_auth_token("34sB8TH11J6NAwauwayUKbbIhdM_6NK1JKh4kidkKyjXCudoz")

# Start ngrok
public_url = ngrok.connect(5000)
print(f"🌐 Your app is LIVE at: {public_url}")
print("⚠️ Keep this cell running!")

# Run Flask app
# !python app.py
# Out:
# 🌐 Your app is LIVE at: NgrokTunnel: "https://c6df8856a14c.ngrok-free.app" -> "http://localhost:5000"
# ⚠️ Keep this cell running!
#  * Serving Flask app 'app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 393-811-921
# 127.0.0.1 - - [01/Nov/2025 11:31:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2025 11:31:44] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [01/Nov/2025 11:31:55] "GET /documents HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2025 11:36:01] "POST /upload-document HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2025 11:36:07] "GET /documents HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Nov/2025 11:36:11] "GET /documents HTTP/1.1" 200 -
# ...
